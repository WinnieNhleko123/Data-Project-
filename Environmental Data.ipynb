# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = 'https://en.wikipedia.org/wiki/Environmental_protection'

# %%
response = requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.text,'html')
print(soup)
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-enabled vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-toc-available" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Environmental protection - Wikipedia</title>
# ...

# %%
table = soup.find('table')
table
# Out:
# <table class="box-Update plainlinks metadata ambox ambox-content ambox-Update" role="presentation"><tbody><tr><td class="mbox-image"><div class="mbox-image-div"><span typeof="mw:File"><span><img alt="" class="mw-file-element" data-file-height="290" data-file-width="360" decoding="async" height="34" src="//upload.wikimedia.org/wikipedia/commons/thumb/5/53/Ambox_current_red_Americas.svg/42px-Ambox_current_red_Americas.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/5/53/Ambox_current_red_Americas.svg/63px-Ambox_current_red_Americas.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/5/53/Ambox_current_red_Americas.svg/84px-Ambox_current_red_Americas.svg.png 2x" width="42"/></span></span></div></td><td class="mbox-text"><div class="mbox-text-span">This article needs to be <b>updated</b>.<span class="hide-when-compact"> Please help update this article to reflect recent events or newly available information.</span> <span class="date-container"><i>(<span class="dat
# ...

# %%
heading = soup.find_all('h1')

# %%
heading
# Out:
# [<h1 class="firstHeading mw-first-heading" id="firstHeading"><span class="mw-page-title-main">Environmental protection</span></h1>]

# %%
table_heading=soup.find_all('caption')

table_heading
# Out:
# [<caption>Pollution control instruments in China
#  </caption>]

# %%
table_data=soup.find("table",class_ ="wikitable")
table_data
# Out:
# <table class="wikitable">
# <tbody><tr>
# <th>Command-and-control</th>
# <th>Economic incentives</th>
# <th>Voluntary instruments</th>
# <th>Public participation
# </th></tr>
# <tr>
# <td>Concentration-based pollution discharge controls</td>
# <td>Pollution levy fee</td>
# <td>Environmental labeling system</td>
# <td>Clean-up campaign
# </td></tr>
# <tr>
# <td>Mass-based controls on total provincial discharge</td>
# <td>Non-compliance fines</td>
# <td>ISO 14000 system</td>
# <td>Environmental awareness campaign
# </td></tr>
# <tr>
# <td>Environmental impact assessments (EIA)</td>
# <td>Discharge permit system</td>
# <td>Cleaner production</td>
# <td>Air pollution index
# </td></tr>
# <tr>
# <td>Three synchronization program</td>
# <td>Sulfur emission fee</td>
# <td>NGOs</td>
# <td>Water quality disclosure
# </td></tr>
# <tr>
# <td>Deadline transmission trading</td>
# <td></td>
# <td>Administrative permission hearing
# </td></tr>
# <tr>
# <td>Centralized pollution control</td>
# ...

# %%
#<table class="wikitable">#

# %%
x=table_data.find_all('th') # headers
x
# Out:
# [<th>Command-and-control</th>,
#  <th>Economic incentives</th>,
#  <th>Voluntary instruments</th>,
#  <th>Public participation
#  </th>]

# %%
table_data_titles=[title.text.strip() for title in x]
table_data_titles
# Out:
# ['Command-and-control',
#  'Economic incentives',
#  'Voluntary instruments',
#  'Public participation']

# %%
df=pd.DataFrame(columns=table_data_titles)
df
# Out:
# Empty DataFrame
# Columns: [Command-and-control, Economic incentives, Voluntary instruments, Public participation]
# Index: []

# %%
column_data=table_data.find_all("td")

# %%
print(column_data)
# Out:
# [<td>Concentration-based pollution discharge controls</td>, <td>Pollution levy fee</td>, <td>Environmental labeling system</td>, <td>Clean-up campaign
# </td>, <td>Mass-based controls on total provincial discharge</td>, <td>Non-compliance fines</td>, <td>ISO 14000 system</td>, <td>Environmental awareness campaign
# </td>, <td>Environmental impact assessments (EIA)</td>, <td>Discharge permit system</td>, <td>Cleaner production</td>, <td>Air pollution index
# </td>, <td>Three synchronization program</td>, <td>Sulfur emission fee</td>, <td>NGOs</td>, <td>Water quality disclosure
# </td>, <td>Deadline transmission trading</td>, <td></td>, <td>Administrative permission hearing
# </td>, <td>Centralized pollution control</td>, <td>Subsidies for energy saving products</td>, <td></td>, <td>
# </td>, <td>Two compliance policy</td>, <td>Regulation on refuse credit to high-polluting firms</td>, <td></td>, <td>
# </td>, <td>Environmental compensation fee</td>, <td></td>, <td></td>, <td>
# </td>]

# %%
for row in column_data[1:]:
    # Find all <td> elements in the current row
    row_data = row.find_all("td")
    # Extract text from each <td> element and create a list of cell contents
    individual_row_data = [ data.text.strip() for data in row_data]
    #length=len(df)
    df.loc[length]= individual_row_data
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[366], line 7
#       5 individual_row_data = [ data.text.strip() for data in row_data]
#       6 #length=len(df)
# ----> 7 df.loc[length]= individual_row_data
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:911, in _LocationIndexer.__setitem__(self, key, value)
#     908 self._has_valid_setitem_indexer(key)
#     910 iloc = self if self.name == "iloc" else self.obj.iloc
# --> 911 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1932, in _iLocIndexer._setitem_with_indexer(self, indexer, value, name)
#    1929     indexer, missing = convert_missing_indexer(indexer)
#    1931     if missing:
# -> 1932         self._setitem_with_indexer_missing(indexer, value)
#    1933         return
#    1935 if name == "loc":
# ...

# %%
individual_row_data
# Out:
# []
